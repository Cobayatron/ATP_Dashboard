# %%
Importamos todo lo que se nos ocurre y vamos viendo en el curso

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# Empezamos intentando tener una lista de todos los jugadores que aparecen fusionando las columnas winner y loser de los csv pero borrando los repetidos.

# %%
anos_list=[]
for i in range(1998,2024):
    ano=pd.read_csv(f'atp_matches_{i}.csv')
    anos_list.append(ano)
    #Con esto se construye una lista donde cada elemento es un csv de los que hemos cargado

# %%
all=pd.concat(anos_list)

# %%
all
# Out:
#                             tourney_id                  tourney_name surface  \
# 0                             1998-339                      Adelaide    Hard
# 1                             1998-339                      Adelaide    Hard
# 2                             1998-339                      Adelaide    Hard
# 3                             1998-339                      Adelaide    Hard
# 4                             1998-339                      Adelaide    Hard
# ...                                ...                           ...     ...
# 2981  2023-M-DC-2023-WG2-PO-RSA-LUX-01  Davis Cup WG2 PO: RSA vs LUX     NaN
# 2982  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
# 2983  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
# 2984  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
# 2985  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
#
# ...
